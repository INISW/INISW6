# %% [markdown]
# ### 사전 준비

# %%
# !pip install transformers==4.29 torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.29
#   Downloading transformers-4.29.0-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 85.4 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers==4.29)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.29)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 117.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.29) (4.65.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.29) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.29) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.29) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.29) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.29) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 tokenizers-0.13.3 transformers-4.29.0

# %%
# !pip install pycocoevalcap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pycocoevalcap) (2.0.6)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.16.0)
# Installing collected packages: pycocoevalcap
# Successfully installed pycocoevalcap-1.2

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.1)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import json
import os
from PIL import Image
from torch import nn
import torch
import time

# %%
class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        encoding = self.processor(images=item["image"], text=item["text"], padding="max_length", return_tensors="pt")

        encoding = {k:v.squeeze() for k,v in encoding.items()}
        return encoding

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 모델 및 process 준비

# %%
from transformers import  AutoProcessor
from transformers import AutoModelForCausalLM
mode = "microsoft/git-base"
processor = AutoProcessor.from_pretrained('/content/drive/MyDrive/재원/model/caption/git/preprocessor')
model = AutoModelForCausalLM.from_pretrained(mode)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/707M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]

# %% [markdown]
# ### 옵션

# %%
option = {
    'start': 0,
    'num': 5000,
    'batch_size':4,
}

# %% [markdown]
# ### 데이터셋 준비 path는 알아서 잘 조정하기 - 1000개당 3분 정도 걸림

# %%
#zip 풀기
# !unzip -qq '/content/drive/MyDrive/data/imagedata.zip' -d '/content'

# %%
labelpath="/content/caption.json"
with open(labelpath, 'r',encoding = 'utf-8' or 'cp949' ) as f: # json 파일 접근
    captions = json.load(f)
import random
random.seed(777)
random.shuffle(captions)

# %%
def image_list(captions,dir,n,m): # 이미지 데이터 가져오기
    imagelist=[]
    for i in range(n,n+m):
        path = dir+'/'+captions[i]['image']
        image = Image.open(path)
        imagelist.append(image)
    return imagelist

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
ImageList = image_list(captions,'/content/imagedata',option['start'],option['num'])

# %%
data = [{'text':captions[i]['label'],'image':ImageList[i]} for i in range(option['start'],option['start']+option['num'])]

# %%
train_dataset = ImageCaptioningDataset(data[:int(0.8*option['num'])], processor)
val_dataset = ImageCaptioningDataset(data[int(0.8*option['num']):], processor)
train_dataloader = DataLoader(train_dataset,shuffle=False,batch_size = option['batch_size'])
val_dataloader = DataLoader(val_dataset,shuffle=False,batch_size = option['batch_size'])

# %%
num_train = int(0.8*option['num']/option['batch_size'])
num_test = int(0.2*option['num']/option['batch_size'])

# %% [markdown]
# ### 성능 평가 코드

# %%
def gen_captions(captions,filename):
    gen = []
    for i in range(len(captions)):
        gen.append({'image_id': i+1, 'caption': captions[i]})
    with open(filename,'w') as f:
      json.dump(gen,f)

# %%
def make_gt(captions,filename):
    annotations=[]
    images = []
    for i in range(len(captions)):
        annotations.append({'image_id': i+1, 'caption': captions[i],'id': i+1})
        images.append({'id':i+1})
    gt_captions ={
        'annotations': annotations,
        'images': images
    }
    with open(filename,'w') as f:
      json.dump(gt_captions,f)

# %%
import json
import os
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap

def coco_caption_eval(annotation_file, results_file):

    coco = COCO(annotation_file)
    coco_result = coco.loadRes(results_file)

    coco_eval = COCOEvalCap(coco, coco_result)
    coco_eval.evaluate()

    # print output evaluation scores
    for metric, score in coco_eval.eval.items():
        print(f'{metric}: {score:.3f}')

    return coco_eval

# %% [markdown]
# ### finetuning 진행

# %%
import torch
train_cpath = '/content/drive/MyDrive/재원/captions/none/train'
val_cpath = '/content/drive/MyDrive/재원/captions/none/val'
train_rpath = '/content/drive/MyDrive/재원/captions/none/train_real.json'
val_rpath = '/content/drive/MyDrive/재원/captions/none/val_real.json'
train_hist=[]
val_hist = []
train_eval = []
val_eval = []

# %%
make_gt([item['text'] for item in data][:int(0.8*option['num'])],train_rpath) # train의 진짜 caption
make_gt([item['text'] for item in data][int(0.8*option['num']):],val_rpath)#val의 진짜 caption

# %%
lr = 1e-5
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
E = 10

for epoch in range(E):
    model.train()
    Loss = 0

    train_caption = []
    for idx, batch in enumerate(train_dataloader):
        model.train()
        input_ids = batch.pop("input_ids").to(device)
        pixel_values = batch.pop("pixel_values").to(device)
        outputs = model(input_ids=input_ids,pixel_values=pixel_values, labels=input_ids)
        loss = outputs.loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #성능을 보기 위한 작업

        with torch.no_grad():
            model.eval()
            train_caption+=processor.batch_decode(model.generate(pixel_values=pixel_values,max_length = 100),skip_special_tokens=True)
        Loss+=loss.tolist()


    train_hist.append(Loss/len(train_dataloader))


    #validation진행

    val = 0
    val_caption =[]
    with torch.no_grad():
        model.eval()
        for idx, batch in enumerate(val_dataloader):
            input_ids = batch.pop("input_ids").to(device)
            pixel_values = batch.pop("pixel_values").to(device)
            outputs = model(input_ids=input_ids,pixel_values=pixel_values, labels=input_ids)

            #성능을 보기위한 작업
            val_caption+=processor.batch_decode(model.generate(pixel_values=pixel_values,max_length = 100),skip_special_tokens=True)
            val+=outputs.loss.tolist()

    val_hist.append(val/len(val_dataloader))

    #checkpoint
    if val_hist[-1]==min(val_hist):
        torch.save(model,'/content/drive/MyDrive/재원/model/caption/git/git_none_all.pt')

    #Epoch 출력
    print("Epoch {}회차 - val_Loss:{}, ".format(epoch+1,val*option['batch_size']/(0.2*option['num'])))

    #epoch의 caption들 저장 및 성능 출력을 위한 코드들
    gen_captions(train_caption,train_cpath+'/'+str(epoch+1)+'.json')
    gen_captions(val_caption,val_cpath+'/'+str(epoch+1)+'.json')
    train_eval.append(coco_caption_eval(train_rpath,train_cpath+'/'+str(epoch+1)+'.json').eval.items())
    val_eval.append(coco_caption_eval(val_rpath,val_cpath+'/'+str(epoch+1)+'.json').eval.items())
# Out:
# Epoch 1회차 - val_Loss:0.6750589841604233,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# Downloading stanford-corenlp-3.6.0 for SPICE ...
# Progress: 384.5M / 384.5M (100.0%)
# Extracting stanford-corenlp-3.6.0 ...
# Done.
# computing Bleu score...
# {'testlen': 21467, 'reflen': 21653, 'guess': [21467, 19867, 18267, 16667], 'correct': [17048, 11617, 7954, 5693]}
# ratio: 0.991409966286381
# Bleu_1: 0.787
# Bleu_2: 0.676
# Bleu_3: 0.582
# Bleu_4: 0.508
# computing METEOR score...
# METEOR: 0.400
# computing Rouge score...
# ROUGE_L: 0.748
# computing CIDEr score...
# CIDEr: 3.309
# computing SPICE score...
# SPICE: 0.508
# Bleu_1: 0.787
# Bleu_2: 0.676
# Bleu_3: 0.582
# Bleu_4: 0.508
# METEOR: 0.400
# ROUGE_L: 0.748
# CIDEr: 3.309
# SPICE: 0.508
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5810, 'reflen': 5425, 'guess': [5810, 5410, 5010, 4610], 'correct': [4578, 3204, 2289, 1658]}
# ratio: 1.0709677419352863
# Bleu_1: 0.788
# Bleu_2: 0.683
# Bleu_3: 0.597
# Bleu_4: 0.526
# computing METEOR score...
# METEOR: 0.429
# computing Rouge score...
# ROUGE_L: 0.773
# computing CIDEr score...
# CIDEr: 3.791
# computing SPICE score...
# SPICE: 0.487
# Bleu_1: 0.788
# Bleu_2: 0.683
# Bleu_3: 0.597
# Bleu_4: 0.526
# METEOR: 0.429
# ROUGE_L: 0.773
# CIDEr: 3.791
# SPICE: 0.487
# Epoch 2회차 - val_Loss:0.0735383590310812,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21697, 'reflen': 21653, 'guess': [21697, 20097, 18497, 16897], 'correct': [18458, 13749, 10349, 7965]}
# ratio: 1.0020320509859602
# Bleu_1: 0.851
# Bleu_2: 0.763
# Bleu_3: 0.688
# Bleu_4: 0.626
# computing METEOR score...
# METEOR: 0.457
# computing Rouge score...
# ROUGE_L: 0.821
# computing CIDEr score...
# CIDEr: 4.727
# computing SPICE score...
# SPICE: 0.591
# Bleu_1: 0.851
# Bleu_2: 0.763
# Bleu_3: 0.688
# Bleu_4: 0.626
# METEOR: 0.457
# ROUGE_L: 0.821
# CIDEr: 4.727
# SPICE: 0.591
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5392, 'reflen': 5425, 'guess': [5392, 4992, 4592, 4192], 'correct': [4511, 3327, 2453, 1894]}
# ratio: 0.993917050691061
# Bleu_1: 0.832
# Bleu_2: 0.742
# Bleu_3: 0.664
# Bleu_4: 0.602
# computing METEOR score...
# METEOR: 0.441
# computing Rouge score...
# ROUGE_L: 0.807
# computing CIDEr score...
# CIDEr: 4.427
# computing SPICE score...
# SPICE: 0.575
# Bleu_1: 0.832
# Bleu_2: 0.742
# Bleu_3: 0.664
# Bleu_4: 0.602
# METEOR: 0.441
# ROUGE_L: 0.807
# CIDEr: 4.427
# SPICE: 0.575
# Epoch 3회차 - val_Loss:0.03661377338692546,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21491, 'reflen': 21653, 'guess': [21491, 19891, 18291, 16691], 'correct': [19291, 15371, 12383, 10112]}
# ratio: 0.9925183577332937
# Bleu_1: 0.891
# Bleu_2: 0.827
# Bleu_3: 0.771
# Bleu_4: 0.725
# computing METEOR score...
# METEOR: 0.505
# computing Rouge score...
# ROUGE_L: 0.870
# computing CIDEr score...
# CIDEr: 6.084
# computing SPICE score...
# SPICE: 0.677
# Bleu_1: 0.891
# Bleu_2: 0.827
# Bleu_3: 0.771
# Bleu_4: 0.725
# METEOR: 0.505
# ROUGE_L: 0.870
# CIDEr: 6.084
# SPICE: 0.677
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5373, 'reflen': 5425, 'guess': [5373, 4973, 4573, 4173], 'correct': [4532, 3363, 2483, 1905]}
# ratio: 0.9904147465435962
# Bleu_1: 0.835
# Bleu_2: 0.748
# Bleu_3: 0.670
# Bleu_4: 0.607
# computing METEOR score...
# METEOR: 0.445
# computing Rouge score...
# ROUGE_L: 0.814
# computing CIDEr score...
# CIDEr: 4.431
# computing SPICE score...
# SPICE: 0.606
# Bleu_1: 0.835
# Bleu_2: 0.748
# Bleu_3: 0.670
# Bleu_4: 0.607
# METEOR: 0.445
# ROUGE_L: 0.814
# CIDEr: 4.431
# SPICE: 0.606
# Epoch 4회차 - val_Loss:0.02631295459344983,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21437, 'reflen': 21653, 'guess': [21437, 19837, 18237, 16637], 'correct': [20001, 16785, 14187, 12093]}
# ratio: 0.9900244769777402
# Bleu_1: 0.924
# Bleu_2: 0.880
# Bleu_3: 0.841
# Bleu_4: 0.809
# computing METEOR score...
# METEOR: 0.554
# computing Rouge score...
# ROUGE_L: 0.911
# computing CIDEr score...
# CIDEr: 7.296
# computing SPICE score...
# SPICE: 0.763
# Bleu_1: 0.924
# Bleu_2: 0.880
# Bleu_3: 0.841
# Bleu_4: 0.809
# METEOR: 0.554
# ROUGE_L: 0.911
# CIDEr: 7.296
# SPICE: 0.763
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5588, 'reflen': 5425, 'guess': [5588, 5188, 4788, 4388], 'correct': [4566, 3335, 2415, 1803]}
# ratio: 1.0300460829491187
# Bleu_1: 0.817
# Bleu_2: 0.725
# Bleu_3: 0.642
# Bleu_4: 0.574
# computing METEOR score...
# METEOR: 0.440
# computing Rouge score...
# ROUGE_L: 0.801
# computing CIDEr score...
# CIDEr: 4.162
# computing SPICE score...
# SPICE: 0.571
# Bleu_1: 0.817
# Bleu_2: 0.725
# Bleu_3: 0.642
# Bleu_4: 0.574
# METEOR: 0.440
# ROUGE_L: 0.801
# CIDEr: 4.162
# SPICE: 0.571
# Epoch 5회차 - val_Loss:0.022691318430006505,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21450, 'reflen': 21653, 'guess': [21450, 19850, 18250, 16650], 'correct': [20409, 17572, 15213, 13203]}
# ratio: 0.9906248556781513
# Bleu_1: 0.943
# Bleu_2: 0.909
# Bleu_3: 0.880
# Bleu_4: 0.856
# computing METEOR score...
# METEOR: 0.586
# computing Rouge score...
# ROUGE_L: 0.932
# computing CIDEr score...
# CIDEr: 7.974
# computing SPICE score...
# SPICE: 0.817
# Bleu_1: 0.943
# Bleu_2: 0.909
# Bleu_3: 0.880
# Bleu_4: 0.856
# METEOR: 0.586
# ROUGE_L: 0.932
# CIDEr: 7.974
# SPICE: 0.817
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5346, 'reflen': 5425, 'guess': [5346, 4946, 4546, 4146], 'correct': [4433, 3224, 2328, 1769]}
# ratio: 0.9854377880182514
# Bleu_1: 0.817
# Bleu_2: 0.724
# Bleu_3: 0.642
# Bleu_4: 0.578
# computing METEOR score...
# METEOR: 0.429
# computing Rouge score...
# ROUGE_L: 0.792
# computing CIDEr score...
# CIDEr: 4.193
# computing SPICE score...
# SPICE: 0.560
# Bleu_1: 0.817
# Bleu_2: 0.724
# Bleu_3: 0.642
# Bleu_4: 0.578
# METEOR: 0.429
# ROUGE_L: 0.792
# CIDEr: 4.193
# SPICE: 0.560
# Epoch 6회차 - val_Loss:0.021514077577739953,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21437, 'reflen': 21653, 'guess': [21437, 19837, 18237, 16637], 'correct': [20737, 18236, 16075, 14169]}
# ratio: 0.9900244769777402
# Bleu_1: 0.958
# Bleu_2: 0.934
# Bleu_3: 0.913
# Bleu_4: 0.895
# computing METEOR score...
# METEOR: 0.618
# computing Rouge score...
# ROUGE_L: 0.951
# computing CIDEr score...
# CIDEr: 8.546
# computing SPICE score...
# SPICE: 0.863
# Bleu_1: 0.958
# Bleu_2: 0.934
# Bleu_3: 0.913
# Bleu_4: 0.895
# METEOR: 0.618
# ROUGE_L: 0.951
# CIDEr: 8.546
# SPICE: 0.863
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5381, 'reflen': 5425, 'guess': [5381, 4981, 4581, 4181], 'correct': [4532, 3324, 2426, 1838]}
# ratio: 0.991889400921476
# Bleu_1: 0.835
# Bleu_2: 0.744
# Bleu_3: 0.662
# Bleu_4: 0.597
# computing METEOR score...
# METEOR: 0.442
# computing Rouge score...
# ROUGE_L: 0.808
# computing CIDEr score...
# CIDEr: 4.276
# computing SPICE score...
# SPICE: 0.586
# Bleu_1: 0.835
# Bleu_2: 0.744
# Bleu_3: 0.662
# Bleu_4: 0.597
# METEOR: 0.442
# ROUGE_L: 0.808
# CIDEr: 4.276
# SPICE: 0.586
# Epoch 7회차 - val_Loss:0.020743484520353378,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21480, 'reflen': 21653, 'guess': [21480, 19880, 18280, 16680], 'correct': [20967, 18674, 16657, 14809]}
# ratio: 0.992010344986792
# Bleu_1: 0.968
# Bleu_2: 0.950
# Bleu_3: 0.934
# Bleu_4: 0.921
# computing METEOR score...
# METEOR: 0.644
# computing Rouge score...
# ROUGE_L: 0.963
# computing CIDEr score...
# CIDEr: 8.896
# computing SPICE score...
# SPICE: 0.895
# Bleu_1: 0.968
# Bleu_2: 0.950
# Bleu_3: 0.934
# Bleu_4: 0.921
# METEOR: 0.644
# ROUGE_L: 0.963
# CIDEr: 8.896
# SPICE: 0.895
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5398, 'reflen': 5425, 'guess': [5398, 4998, 4598, 4198], 'correct': [4537, 3364, 2482, 1911]}
# ratio: 0.9950230414744708
# Bleu_1: 0.836
# Bleu_2: 0.748
# Bleu_3: 0.670
# Bleu_4: 0.608
# computing METEOR score...
# METEOR: 0.445
# computing Rouge score...
# ROUGE_L: 0.811
# computing CIDEr score...
# CIDEr: 4.428
# computing SPICE score...
# SPICE: 0.590
# Bleu_1: 0.836
# Bleu_2: 0.748
# Bleu_3: 0.670
# Bleu_4: 0.608
# METEOR: 0.445
# ROUGE_L: 0.811
# CIDEr: 4.428
# SPICE: 0.590
# Epoch 8회차 - val_Loss:0.01908194768242538,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21488, 'reflen': 21653, 'guess': [21488, 19888, 18288, 16688], 'correct': [21121, 19001, 17085, 15278]}
# ratio: 0.9923798088024296
# Bleu_1: 0.975
# Bleu_2: 0.962
# Bleu_3: 0.950
# Bleu_4: 0.939
# computing METEOR score...
# METEOR: 0.667
# computing Rouge score...
# ROUGE_L: 0.972
# computing CIDEr score...
# CIDEr: 9.158
# computing SPICE score...
# SPICE: 0.922
# Bleu_1: 0.975
# Bleu_2: 0.962
# Bleu_3: 0.950
# Bleu_4: 0.939
# METEOR: 0.667
# ROUGE_L: 0.972
# CIDEr: 9.158
# SPICE: 0.922
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5403, 'reflen': 5425, 'guess': [5403, 5003, 4603, 4203], 'correct': [4518, 3312, 2417, 1853]}
# ratio: 0.9959447004606459
# Bleu_1: 0.833
# Bleu_2: 0.741
# Bleu_3: 0.660
# Bleu_4: 0.596
# computing METEOR score...
# METEOR: 0.439
# computing Rouge score...
# ROUGE_L: 0.807
# computing CIDEr score...
# CIDEr: 4.274
# computing SPICE score...
# SPICE: 0.597
# Bleu_1: 0.833
# Bleu_2: 0.741
# Bleu_3: 0.660
# Bleu_4: 0.596
# METEOR: 0.439
# ROUGE_L: 0.807
# CIDEr: 4.274
# SPICE: 0.597
# Epoch 9회차 - val_Loss:0.018797806170769035,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21521, 'reflen': 21653, 'guess': [21521, 19921, 18321, 16721], 'correct': [21279, 19314, 17495, 15759]}
# ratio: 0.9939038470419344
# Bleu_1: 0.983
# Bleu_2: 0.973
# Bleu_3: 0.965
# Bleu_4: 0.958
# computing METEOR score...
# METEOR: 0.693
# computing Rouge score...
# ROUGE_L: 0.980
# computing CIDEr score...
# CIDEr: 9.445
# computing SPICE score...
# SPICE: 0.943
# Bleu_1: 0.983
# Bleu_2: 0.973
# Bleu_3: 0.965
# Bleu_4: 0.958
# METEOR: 0.693
# ROUGE_L: 0.980
# CIDEr: 9.445
# SPICE: 0.943
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5418, 'reflen': 5425, 'guess': [5418, 5018, 4618, 4218], 'correct': [4580, 3406, 2524, 1947]}
# ratio: 0.9987096774191707
# Bleu_1: 0.844
# Bleu_2: 0.757
# Bleu_3: 0.679
# Bleu_4: 0.616
# computing METEOR score...
# METEOR: 0.449
# computing Rouge score...
# ROUGE_L: 0.818
# computing CIDEr score...
# CIDEr: 4.456
# computing SPICE score...
# SPICE: 0.610
# Bleu_1: 0.844
# Bleu_2: 0.757
# Bleu_3: 0.679
# Bleu_4: 0.616
# METEOR: 0.449
# ROUGE_L: 0.818
# CIDEr: 4.456
# SPICE: 0.610
# Epoch 10회차 - val_Loss:0.02020240477286279,
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 21555, 'reflen': 21653, 'guess': [21555, 19955, 18355, 16755], 'correct': [21386, 19542, 17785, 16098]}
# ratio: 0.9954740682583939
# Bleu_1: 0.988
# Bleu_2: 0.981
# Bleu_3: 0.976
# Bleu_4: 0.971
# computing METEOR score...
# METEOR: 0.717
# computing Rouge score...
# ROUGE_L: 0.987
# computing CIDEr score...
# CIDEr: 9.625
# computing SPICE score...
# SPICE: 0.961
# Bleu_1: 0.988
# Bleu_2: 0.981
# Bleu_3: 0.976
# Bleu_4: 0.971
# METEOR: 0.717
# ROUGE_L: 0.987
# CIDEr: 9.625
# SPICE: 0.961
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'testlen': 5615, 'reflen': 5425, 'guess': [5615, 5215, 4815, 4415], 'correct': [4578, 3345, 2449, 1841]}
# ratio: 1.0350230414744634
# Bleu_1: 0.815
# Bleu_2: 0.723
# Bleu_3: 0.643
# Bleu_4: 0.577
# computing METEOR score...
# METEOR: 0.441
# computing Rouge score...
# ROUGE_L: 0.798
# computing CIDEr score...
# CIDEr: 4.118
# computing SPICE score...
# SPICE: 0.552
# Bleu_1: 0.815
# Bleu_2: 0.723
# Bleu_3: 0.643
# Bleu_4: 0.577
# METEOR: 0.441
# ROUGE_L: 0.798
# CIDEr: 4.118
# SPICE: 0.552

# %%
import json
total_list =[train_hist,[dict(item.mapping) for item in train_eval],val_hist,[dict(item.mapping) for item in val_eval]]
with open('/content/drive/MyDrive/재원/eval/loss/git_none_plot.json','w') as f:
    json.dump(total_list,f)
